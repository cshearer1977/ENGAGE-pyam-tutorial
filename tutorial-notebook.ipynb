# %% [markdown]
# <img style="float: right; height: 80px; padding-left: 20px;" src="_static/ENGAGE.png">
#
# # ENGAGE Capacity Building Workshop: the *pyam* package
#
# <br>
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/github/license/danielhuppmann/ENGAGE-pyam-tutorial">
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/badge/python-≥3.8,<3.12-blue?logo=python&logoColor=white">
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/badge/code%20style-black-000000.svg">
# <br><br>
#
# Copyright 2022-2023 Daniel Huppmann; this repository is released under the [MIT License](https://github.com/danielhuppmann/ENGAGE-pyam-tutorial/blob/main/LICENSE).
#
# ## Overview
#
# This notebook illustrates a number of features of the **pyam** package
# presented as part of the *hands-on tutorial sessions*
# of the **NAVIGATE-ENGAGE Summer School 2023 on Integrated-Assessment Modeling**.
# This workshop was organized as part of the Horizon 2020 project ENGAGE
# ([link](https://www.engage-climate.org/navigate-engage-summer-school-2023/)).
#
# The slides for the related presentation are available
# at https://doi.org/10.5281/zenodo.8112529 (ZENODO).
#
# This tutorial is based on the advanced assignment
# of the [Modelling Lab](https://github.com/danielhuppmann/climate-risks-academy-2021),
# which was part of the *Climate Risks Academy 2021* organized by
# the European University Institute (EUI) Florence School of Banking and Finance
# in cooperation with Oliver Wyman.
#
# ### Tutorial data source
#
# The scenario data used in this tutorial notebook is taken from
# the **NGFS Scenario Ensemble**, Phase 3,
# see Richters et al, 2022 ([link](https://www.ngfs.net/sites/default/files/medias/documents/ngfs_climate_scenarios_for_central_banks_and_supervisors_.pdf.pdf)).
#
# The data was downloaded from the following scenario database:
# > **Emissions scenario database of the European Scientific Advisory Board on Climate Change, hosted by IIASA**
# > Release 2.0
# > European Scientific Advisory Board on Climate Change, 2023
# > doi: 	https://doi.org/10.5281/zenodo.7660150
# > url: 	https://data.ece.iiasa.ac.at/eu-climate-advisory-board
#
# ### Read the docs
#
# See the comprehensive documentation of the **pyam** package on
# [ReadTheDocs](https://pyam-iamc.readthedocs.io/en/stable/tutorials.html)!
#
#
# ### Installation
#
# You can install the **pyam** package using the following command -
# note the subtle naming difference on [pypi.org](https://pypi.org/project/pyam-iamc/).
#
# ```
# pip install pyam-iamc
# ```
#
# [Read the docs](https://pyam-iamc.readthedocs.io/en/stable/install.html) for alternative installation options.

# %%
import pyam

# %% [markdown]
# ## Import and inspect the tutorial data
#
# The tutorial datatset is saved as an Excel spreadsheet in this repository.

# %%
df = pyam.IamDataFrame("data/ngfs_data_snapshot.xlsx")
# Out:
# pyam.core - INFO: Reading file data/ngfs_data_snapshot.xlsx
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)

# %% [markdown]
# Just calling an **IamDataFrame** prints an overview of all index dimensions and coordinates.

# %%
df
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.1-M-R12, REMIND-MAgPIE 3.0-4.4 (2)
#  * scenario : NGFS-Below 2C, NGFS-Current Policies, ... NGFS-Net Zero 2050 (4)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : ... (10)
#    unit     : EJ/yr, K, Mt CH4/yr, Mt CO2/yr, US$2010/t CO2 (5)
#    year     : 2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, ... 2100 (14)
# Meta indicators:
#    exclude (bool) False (1)

# %%
df.head()
# Out:
#                          model       scenario region  \
# 0  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World
# 1  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World
# 2  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World
# 3  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World
# 4  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World
#
#                                             variable unit  year     value
# 0  AR6 climate diagnostics|Surface Temperature (G...    K  2010  0.975563
# 1  AR6 climate diagnostics|Surface Temperature (G...    K  2015  1.115580
# 2  AR6 climate diagnostics|Surface Temperature (G...    K  2020  1.236552
# 3  AR6 climate diagnostics|Surface Temperature (G...    K  2025  1.422769
# 4  AR6 climate diagnostics|Surface Temperature (G...    K  2030  1.508911

# %% [markdown]
# Because there are more scenarios and variables than can be displayed in one line, the summary only shows a few items.
#
# We can easily display all items of an index dimension or a coordinate individually using attributes of the **IamDataFrame**.

# %%
df.model
# Out:
# ['MESSAGEix-GLOBIOM 1.1-M-R12', 'REMIND-MAgPIE 3.0-4.4']

# %%
df.region
# Out:
# ['World']

# %%
df.scenario
# Out:
# ['NGFS-Below 2C',
#  'NGFS-Current Policies',
#  'NGFS-Nationally Determined Contributions (NDCs)',
#  'NGFS-Net Zero 2050']

# %%
df.variable
# Out:
# ['AR6 climate diagnostics|Surface Temperature (GSAT)|MAGICCv7.5.3|50.0th Percentile',
#  'Emissions|CH4',
#  'Emissions|CO2',
#  'Price|Carbon',
#  'Primary Energy|Biomass',
#  'Primary Energy|Coal',
#  'Primary Energy|Gas',
#  'Primary Energy|Non-Biomass Renewables',
#  'Primary Energy|Nuclear',
#  'Primary Energy|Oil']

# %%
df.unit
# Out:
# ['EJ/yr', 'K', 'Mt CH4/yr', 'Mt CO2/yr', 'US$2010/t CO2']

# %%
df.year
# Out:
# [2010,
#  2015,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2060,
#  2070,
#  2080,
#  2090,
#  2100]

# %% [markdown]
# ## Filtering and renaming data
#
# The variable *AR6 climate diagnostics|...* looks inconvenient for scenario analysis, so let's look at it in detail...
#
# The [filter()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.filter) method allows to downselect data by any dimenions, where `*` can be used as a wildcard.
#
# And you can use the [timeseries()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.timeseries) method to show the timeseries data in wide format.

# %%
variable = "AR6 climate diagnostics|Surface Temperature (GSAT)|MAGICCv7.5.3|50.0th Percentile"
df.filter(variable=variable).timeseries()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
#                                                                                                                                                 2010  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     0.975563
#
#                                                                                                                                                 2015  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115580
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115580
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115580
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115580
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115498
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115498
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115498
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.115498
#
#                                                                                                                                                 2020  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.236552
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.234032
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.234537
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.237095
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.236383
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.235106
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.235971
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.237098
#
#                                                                                                                                                 2025  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.422769
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.373457
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.383378
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.427013
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.391714
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.385045
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.390505
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.398752
#
#                                                                                                                                                 2030  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.508911
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.466068
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.475140
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.499106
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.478753
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.494958
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.499343
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.475227
#
#                                                                                                                                                 2035  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.570090
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.597455
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.594303
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.530597
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.576045
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.633090
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.627155
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.542511
#
#                                                                                                                                                 2040  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.605465
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.722430
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.692150
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.525837
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.636270
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.760531
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.728495
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.562190
#
#                                                                                                                                                 2045  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.615490
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.835572
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.770529
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.500646
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.662644
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.883265
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.810807
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.554466
#
#                                                                                                                                                 2050  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.629969
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     1.964146
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.852236
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.490692
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.682477
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.039689
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.899835
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.554864
#
#                                                                                                                                                 2060  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.611463
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.173678
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     1.945803
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.423832
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.671003
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.292740
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.037431
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.498647
#
#                                                                                                                                                 2070  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.572942
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.361829
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.032076
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.366426
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.657563
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.541780
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.164418
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.468983
#
#                                                                                                                                                 2080  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.538557
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.560086
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.100209
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.327748
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.641554
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.770486
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.261765
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.431729
#
#                                                                                                                                                 2090  \
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.516012
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.792284
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.182193
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.321118
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.635570
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     2.982965
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.329991
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.403616
#
#                                                                                                                                                 2100
# model                       scenario                                        region variable                                           unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.501522
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     3.052270
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.267606
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.310345
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  AR6 climate diagnostics|Surface Temperature (GS... K     1.628097
#                             NGFS-Current Policies                           World  AR6 climate diagnostics|Surface Temperature (GS... K     3.196486
#                             NGFS-Nationally Determined Contributions (NDCs) World  AR6 climate diagnostics|Surface Temperature (GS... K     2.388144
#                             NGFS-Net Zero 2050                              World  AR6 climate diagnostics|Surface Temperature (GS... K     1.379396

# %% [markdown]
# We can easily rename index dimensions for easier processing and analysis.

# %%
df.rename(
    variable={variable: "Temperature"},
    unit={"K": "°C"},
    inplace=True,
)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)

# %%
df.filter(variable="Temperature").timeseries()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
#                                                                                                          2010  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    0.975563
#                             NGFS-Current Policies                           World  Temperature °C    0.975563
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    0.975563
#                             NGFS-Net Zero 2050                              World  Temperature °C    0.975563
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    0.975563
#                             NGFS-Current Policies                           World  Temperature °C    0.975563
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    0.975563
#                             NGFS-Net Zero 2050                              World  Temperature °C    0.975563
#
#                                                                                                          2015  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.115580
#                             NGFS-Current Policies                           World  Temperature °C    1.115580
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.115580
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.115580
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.115498
#                             NGFS-Current Policies                           World  Temperature °C    1.115498
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.115498
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.115498
#
#                                                                                                          2020  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.236552
#                             NGFS-Current Policies                           World  Temperature °C    1.234032
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.234537
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.237095
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.236383
#                             NGFS-Current Policies                           World  Temperature °C    1.235106
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.235971
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.237098
#
#                                                                                                          2025  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.422769
#                             NGFS-Current Policies                           World  Temperature °C    1.373457
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.383378
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.427013
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.391714
#                             NGFS-Current Policies                           World  Temperature °C    1.385045
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.390505
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.398752
#
#                                                                                                          2030  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.508911
#                             NGFS-Current Policies                           World  Temperature °C    1.466068
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.475140
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.499106
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.478753
#                             NGFS-Current Policies                           World  Temperature °C    1.494958
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.499343
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.475227
#
#                                                                                                          2035  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.570090
#                             NGFS-Current Policies                           World  Temperature °C    1.597455
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.594303
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.530597
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.576045
#                             NGFS-Current Policies                           World  Temperature °C    1.633090
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.627155
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.542511
#
#                                                                                                          2040  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.605465
#                             NGFS-Current Policies                           World  Temperature °C    1.722430
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.692150
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.525837
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.636270
#                             NGFS-Current Policies                           World  Temperature °C    1.760531
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.728495
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.562190
#
#                                                                                                          2045  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.615490
#                             NGFS-Current Policies                           World  Temperature °C    1.835572
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.770529
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.500646
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.662644
#                             NGFS-Current Policies                           World  Temperature °C    1.883265
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.810807
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.554466
#
#                                                                                                          2050  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.629969
#                             NGFS-Current Policies                           World  Temperature °C    1.964146
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.852236
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.490692
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.682477
#                             NGFS-Current Policies                           World  Temperature °C    2.039689
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.899835
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.554864
#
#                                                                                                          2060  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.611463
#                             NGFS-Current Policies                           World  Temperature °C    2.173678
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    1.945803
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.423832
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.671003
#                             NGFS-Current Policies                           World  Temperature °C    2.292740
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.037431
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.498647
#
#                                                                                                          2070  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.572942
#                             NGFS-Current Policies                           World  Temperature °C    2.361829
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.032076
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.366426
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.657563
#                             NGFS-Current Policies                           World  Temperature °C    2.541780
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.164418
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.468983
#
#                                                                                                          2080  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.538557
#                             NGFS-Current Policies                           World  Temperature °C    2.560086
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.100209
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.327748
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.641554
#                             NGFS-Current Policies                           World  Temperature °C    2.770486
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.261765
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.431729
#
#                                                                                                          2090  \
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.516012
#                             NGFS-Current Policies                           World  Temperature °C    2.792284
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.182193
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.321118
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.635570
#                             NGFS-Current Policies                           World  Temperature °C    2.982965
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.329991
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.403616
#
#                                                                                                          2100
# model                       scenario                                        region variable    unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Temperature °C    1.501522
#                             NGFS-Current Policies                           World  Temperature °C    3.052270
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.267606
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.310345
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Temperature °C    1.628097
#                             NGFS-Current Policies                           World  Temperature °C    3.196486
#                             NGFS-Nationally Determined Contributions (NDCs) World  Temperature °C    2.388144
#                             NGFS-Net Zero 2050                              World  Temperature °C    1.379396

# %% [markdown]
# ## A few simple plots
#
# As a first step to get an idea of the scenario data, let's draw some [plots](https://pyam-iamc.readthedocs.io/en/stable/api/plotting.html).
#
# Why not start with the temperature?

# %%
import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items

# %%
df.filter(variable="Temperature").plot()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# <Axes: title={'center': 'region: World - variable: Temperature'}, xlabel='Year', ylabel='°C'>

# %% [markdown]
# Let's move the legend and apply some styling by model and scenario...

# %%
(
    df.filter(variable="Temperature")
    .plot(
        legend={"loc": "outside right"},
        color="scenario",
        linestyle="model",
    )
)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# <Axes: title={'center': 'region: World - variable: Temperature'}, xlabel='Year', ylabel='°C'>

# %% [markdown]
# ## Unit conversion
#
# Working with different units is a constant headache (and source of errors) when handling energy systems data.
#
# To simplify such tasks, **pyam** incorporates the [**iam-units**](https://github.com/iamconsortium/units) package,
# a community resource for units commonly used in energy-systems modelling, integrated assessment and climate research.
#
# ### Conversion using SI units
#
# The **iam-units** package natively includes all SI units
# by building on the [**pint**](https://pint.readthedocs.io) package.

# %%
df_coal = df.filter(
    model="MESSAGEix-GLOBIOM 1.1-M-R12",
    scenario="NGFS-Current Policies",
    variable="Primary Energy|Coal",
)
df_coal.timeseries()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
#                                                                                           2010  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  153.552995
#
#                                                                                           2015  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  153.020532
#
#                                                                                           2020  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  156.253495
#
#                                                                                          2025  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  147.29581
#
#                                                                                           2030  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  145.551154
#
#                                                                                           2035  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  136.648935
#
#                                                                                           2040  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  138.065263
#
#                                                                                           2045  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  144.186748
#
#                                                                                           2050  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  154.519797
#
#                                                                                           2060  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  176.051253
#
#                                                                                           2070  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  190.081394
#
#                                                                                           2080  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  215.033055
#
#                                                                                           2090  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  245.012833
#
#                                                                                           2100
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal EJ/yr  259.560251

# %%
df_coal.convert_unit("EJ/yr", "TWh/yr").timeseries()
# Out:
#                                                                                              2010  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  42653.609622
#
#                                                                                              2015  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  42505.703397
#
#                                                                                              2020  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  43403.748709
#
#                                                                                              2025  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  40915.502754
#
#                                                                                              2030  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  40430.876065
#
#                                                                                              2035  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  37958.037486
#
#                                                                                              2040  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  38351.462012
#
#                                                                                              2045  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  40051.874391
#
#                                                                                              2050  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  42922.165818
#
#                                                                                              2060  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  48903.125943
#
#                                                                                              2070  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  52800.387132
#
#                                                                                              2080  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  59731.404136
#
#                                                                                              2090  \
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  68059.120267
#
#                                                                                              2100
# model                       scenario              region variable            unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Current Policies World  Primary Energy|Coal TWh/yr  72100.069637

# %% [markdown]
# ### Conversion of greenhouse gase emissions using Global Warming Potentials
#
# The **iam-units** package also includes a module to convert different greenhouse-gas emissions
# by alternative **global-warming-potential (GWP)** metrics.

# %%
ch4_df = df.filter(model="MESSAGEix-GLOBIOM 1.1-M-R12", variable="Emissions|CH4")
ch4_df.timeseries()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
#                                                                                                                   2010  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  333.979307
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  333.979307
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  333.979307
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  333.979307
#
#                                                                                                                   2015  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  342.423178
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  342.423178
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  342.423178
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  342.423178
#
#                                                                                                                   2020  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  319.436079
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  319.436079
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  319.436079
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  319.436079
#
#                                                                                                                   2025  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  233.088788
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  325.889373
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  311.376665
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  213.122198
#
#                                                                                                                   2030  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  205.430174
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  327.795260
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  304.689448
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  182.532839
#
#                                                                                                                   2035  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  186.216065
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  320.465907
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  278.599271
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  162.690444
#
#                                                                                                                   2040  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  168.260361
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  315.932821
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  252.586141
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  145.867106
#
#                                                                                                                   2045  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  146.841220
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  307.565328
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  224.947712
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  128.509620
#
#                                                                                                                   2050  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  128.587069
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  298.128222
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  203.772032
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  113.181335
#
#                                                                                                                   2060  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  110.341226
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  273.935051
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  171.848954
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr   98.325239
#
#                                                                                                                   2070  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr  100.649397
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  244.056188
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  149.979273
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr  100.061387
#
#                                                                                                                   2080  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr   92.007900
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  229.896769
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  135.946196
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr   97.608498
#
#                                                                                                                   2090  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr   86.826818
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  224.364809
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  122.100593
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr   93.134064
#
#                                                                                                                   2100
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CH4/yr   84.332949
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CH4/yr  212.718673
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CH4/yr  111.932262
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CH4/yr   86.947169

# %% [markdown]
# Comparing the climate effect of different greenhouse gases requires a well-defined metric,
# usually the "Global Warming Potential" (GWP) assuming a period of assessment (20 or 100 years)
# as assessed by the IPCC (e.g., AR6).

# %%
ch4_df.convert_unit("Mt CH4/yr", "Mt CO2e/yr", context="AR6GWP100").timeseries()
# Out:
#                                                                                                                     2010  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  9318.022652
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  9318.022652
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  9318.022652
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  9318.022652
#
#                                                                                                                     2015  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  9553.606676
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  9553.606676
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  9553.606676
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  9553.606676
#
#                                                                                                                     2020  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  8912.266612
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  8912.266612
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  8912.266612
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  8912.266612
#
#                                                                                                                     2025  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  6503.177196
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  9092.313498
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  8687.408953
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  5946.109328
#
#                                                                                                                     2030  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  5731.501843
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  9145.487760
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  8500.835591
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  5092.666206
#
#                                                                                                                     2035  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  5195.428227
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  8940.998800
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  7772.919659
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  4539.063382
#
#                                                                                                                     2040  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  4694.464079
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  8814.525698
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  7047.153322
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  4069.692268
#
#                                                                                                                     2045  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  4096.870025
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  8581.072654
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  6276.041168
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  3585.418406
#
#                                                                                                                     2050  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  3587.579238
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  8317.777380
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  5685.239693
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  3157.759233
#
#                                                                                                                     2060  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  3078.520199
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  7642.787910
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  4794.585805
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  2743.274167
#
#                                                                                                                     2070  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  2808.118175
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  6809.167641
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  4184.421721
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  2791.712695
#
#                                                                                                                     2080  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  2567.020397
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  6414.119861
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  3792.898868
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  2723.277088
#
#                                                                                                                     2090  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  2422.468209
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  6259.778164
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  3406.606554
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  2598.440384
#
#                                                                                                                     2100
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  2352.889289
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  5934.850979
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  3122.910112
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  2425.826015

# %%
ch4_df.convert_unit("Mt CH4/yr", "Mt CO2e/yr", context="AR6GWP20").timeseries()
# Out:
#                                                                                                                      2010  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  27119.119689
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  27119.119689
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  27119.119689
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  27119.119689
#
#                                                                                                                      2015  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  27804.762081
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  27804.762081
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  27804.762081
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  27804.762081
#
#                                                                                                                      2020  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  25938.209637
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  25938.209637
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  25938.209637
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  25938.209637
#
#                                                                                                                      2025  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  18926.809618
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  26462.217063
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  25283.785196
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  17305.522490
#
#                                                                                                                      2030  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  16680.930096
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  26616.975130
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  24740.783154
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  14821.666522
#
#                                                                                                                      2035  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  15120.744517
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  26021.831633
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  22622.260798
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  13210.464035
#
#                                                                                                                      2040  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  13662.741335
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  25653.745042
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  20509.994614
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  11844.409039
#
#                                                                                                                      2045  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  11923.507025
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  24974.304643
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  18265.754223
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr  10434.981168
#
#                                                                                                                      2050  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr  10441.270041
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  24208.011587
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  16546.288999
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   9190.324364
#
#                                                                                                                      2060  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr   8959.707533
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  22243.526103
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  13954.135031
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   7984.009404
#
#                                                                                                                      2070  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr   8172.731032
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  19817.362454
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  12178.316980
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   8124.984618
#
#                                                                                                                      2080  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr   7471.041442
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  18667.617661
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr  11038.831114
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   7925.810018
#
#                                                                                                                      2090  \
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr   7050.337583
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  18218.422471
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr   9914.568179
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   7562.485993
#
#                                                                                                                      2100
# model                       scenario                                        region variable      unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Emissions|CH4 Mt CO2e/yr   6847.835494
#                             NGFS-Current Policies                           World  Emissions|CH4 Mt CO2e/yr  17272.756253
#                             NGFS-Nationally Determined Contributions (NDCs) World  Emissions|CH4 Mt CO2e/yr   9088.899681
#                             NGFS-Net Zero 2050                              World  Emissions|CH4 Mt CO2e/yr   7060.110123

# %% [markdown]
# See [this tutorial](https://pyam-iamc.readthedocs.io/en/stable/tutorials/unit_conversion.html#4.-Use-contexts-to-specify-conversion-metrics) for more information on unit conversion!

# %% [markdown]
# ## Computing aggregates
#
# If you look at the list of variables in the scenario data, you'll see that we initially only have sub-categories of *Primary Energy*.
#
# However, **pyam** offers a number of useful functions to aggregate (or downscale) by sectors or regions.
#
# ### Aggregation by sector
#
# By default, the [aggregate()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.aggregate) method
# takes all components of the given variable, in this case `Primary Energy|*`.<br />
# It returns a new **IamDataFrame** - and the cell displays the summary. You will see that the object has exactly one variable now.

# %%
df.aggregate("Primary Energy")
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/utils.py:500: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   matches |= data.str.match(pattern) & depth
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/aggregation.py:203: FutureWarning: The provided callable <function sum at 0x106025080> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.1-M-R12, REMIND-MAgPIE 3.0-4.4 (2)
#  * scenario : NGFS-Below 2C, NGFS-Current Policies, ... NGFS-Net Zero 2050 (4)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : Primary Energy (1)
#    unit     : EJ/yr (1)
#    year     : 2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, ... 2100 (14)
# Meta indicators:
#    exclude (bool) False (1)

# %%
df.aggregate("Primary Energy").plot(legend={"loc": "outside right"})
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/utils.py:500: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   matches |= data.str.match(pattern) & depth
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/aggregation.py:203: FutureWarning: The provided callable <function sum at 0x106025080> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# <Axes: title={'center': 'region: World - variable: Primary Energy'}, xlabel='Year', ylabel='EJ/yr'>

# %%
df.head()
# Out:
#                          model       scenario region     variable unit  year  \
# 0  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2010
# 1  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2015
# 2  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2020
# 3  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2025
# 4  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2030
#
#       value
# 0  0.975563
# 1  1.115580
# 2  1.236552
# 3  1.422769
# 4  1.508911

# %%
df.aggregate("Primary Energy").timeseries()
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/utils.py:500: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   matches |= data.str.match(pattern) & depth
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/aggregation.py:203: FutureWarning: The provided callable <function sum at 0x106025080> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
#                                                                                                                2010  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  530.340479
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  530.340479
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  530.340479
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  530.340479
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  509.951300
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  509.951300
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  509.951300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  509.951300
#
#                                                                                                                2015  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  558.028925
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  558.028925
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  558.028925
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  558.028925
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  544.342100
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  544.342100
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  544.342100
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  544.342100
#
#                                                                                                                2020  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  584.226679
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  584.226679
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  584.226679
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  584.226679
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  570.018300
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  570.018300
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  570.018300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  570.018300
#
#                                                                                                                2025  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  556.372278
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  615.115739
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  606.337549
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  508.072399
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  542.147700
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  588.849000
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  572.580300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  498.468000
#
#                                                                                                                2030  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  545.533710
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  654.720744
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  634.354893
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  479.930453
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  540.590700
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  617.677500
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  590.332300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  484.631500
#
#                                                                                                                2035  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  546.827250
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  691.856902
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  653.209271
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  479.540170
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  514.037900
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  643.497000
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  596.818300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  464.093200
#
#                                                                                                                2040  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  554.001473
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  719.076309
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  665.030744
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  490.141576
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  498.468100
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  669.145200
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  592.633000
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  451.347400
#
#                                                                                                                2045  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  564.262778
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  754.704195
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  682.124346
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  507.161329
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  492.408100
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  699.077700
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  593.300700
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  455.951700
#
#                                                                                                                2050  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  576.439615
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  784.775924
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  701.179279
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  528.849337
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  499.264600
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  735.629700
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  610.220800
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  468.209600
#
#                                                                                                                2060  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  645.939806
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  836.460635
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  735.696852
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  599.357498
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  545.411500
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  797.012400
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  656.590300
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  503.399800
#
#                                                                                                                2070  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  725.851854
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  902.246474
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  804.217025
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  704.854045
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  601.145700
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  856.179800
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  704.777500
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  558.414800
#
#                                                                                                                2080  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr  802.521434
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  996.473122
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  867.144126
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  805.217654
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr  652.914700
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  905.780500
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  753.409100
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr  621.286100
#
#                                                                                                                 2090  \
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr   895.635884
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  1097.324753
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   929.985594
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr   903.012166
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr   693.968900
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr   935.660600
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   787.629800
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr   685.446900
#
#                                                                                                                 2100
# model                       scenario                                        region variable       unit
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                   World  Primary Energy EJ/yr   984.093193
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr  1194.033470
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  1012.757435
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr   987.771345
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                   World  Primary Energy EJ/yr   725.008500
#                             NGFS-Current Policies                           World  Primary Energy EJ/yr   954.747000
#                             NGFS-Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   816.052900
#                             NGFS-Net Zero 2050                              World  Primary Energy EJ/yr   755.850000

# %% [markdown]
# It is often convenient to directly append computed timeseries data to the original object.
# For that, you can use the `append=True` keyword argument.

# %%
df.aggregate("Primary Energy", append=True)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/utils.py:500: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   matches |= data.str.match(pattern) & depth
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/aggregation.py:203: FutureWarning: The provided callable <function sum at 0x106025080> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/y3/1cxltp3j6rn27pc3lkybs7hw0000gn/T/ipykernel_54073/2084355277.py in ?()
# ----> 1 df.aggregate("Primary Energy", append=True)
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, variable, components, method, recursive, append)
#    1272         else:
#    1273             _df = _aggregate(self, variable, components=components, method=method)
#    1274
#    1275         # append to `self` or return as `IamDataFrame`
# -> 1276         return self._finalize(_df, append=append)
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, data, append, **args)
#     229     def _finalize(self, data, append, **args):
#     230         """Append `data` to `self` or return as new IamDataFrame with copy of `meta`"""
#     231         if append:
# --> 232             self.append(data, **args, inplace=True)
#     233         else:
#     234             if data is None or data.empty:
#     235                 return _empty_iamframe(self.dimensions + ["value"])
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, other, ignore_meta_conflict, inplace, verify_integrity, **kwargs)
#     523         # merge `meta` tables
#     524         ret.meta = merge_meta(ret.meta, other.meta, ignore_meta_conflict)
#     525
#     526         # append other.data (verify integrity for no duplicates)
# --> 527         _data = ret._data.append(other._data)
#     528         if verify_integrity:
#     529             verify_index_integrity(_data)
#     530
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'

# %% [markdown]
# When displaying the variables of the **IamDataFrame** again, there is now an additional variable *Primary Energy*.

# %%
df.variable
# Out:
# ['Temperature',
#  'Emissions|CH4',
#  'Emissions|CO2',
#  'Price|Carbon',
#  'Primary Energy|Biomass',
#  'Primary Energy|Coal',
#  'Primary Energy|Gas',
#  'Primary Energy|Non-Biomass Renewables',
#  'Primary Energy|Nuclear',
#  'Primary Energy|Oil']

# %%
df.head()
# Out:
#                          model       scenario region     variable unit  year  \
# 0  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2010
# 1  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2015
# 2  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2020
# 3  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2025
# 4  MESSAGEix-GLOBIOM 1.1-M-R12  NGFS-Below 2C  World  Temperature   °C  2030
#
#       value
# 0  0.975563
# 1  1.115580
# 2  1.236552
# 3  1.422769
# 4  1.508911

# %% [markdown]
# ### Aggregation by region
#
# In the interest of time, the features for regional aggregation and downscaling are not shown in this notebook.
#
# Take a look at [this tutorial](https://pyam-iamc.readthedocs.io/en/stable/tutorials/aggregating_downscaling_consistency.html)
# for more information!

# %% [markdown]
# ## Categorization of scenarios by their temperature outcome
#
# We often want to categorize scenarios by some metrics or indicators.
# As an example, let us divide scenarios into groups "above 2C" and "below 2C".
#
# First, we assign all scenarios to the "above 2C" group,
# and then use the [categorize()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.categorize) method
# to re-assign all scenarios that satisfy certain criteria.

# %%
df.set_meta(meta="above 2C", name="warming-category")

# %%
df.categorize(
    "warming-category", "below 2C",
    criteria={"Temperature": {"up": 2.0}},
)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# pyam.core - INFO: 4 scenarios categorized as `warming-category: below 2C`

# %% [markdown]
# We can inspect the assignment of categories via the `meta` attribute.

# %%
df.meta
# Out:
#                                                                              exclude  \
# model                       scenario
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                      False
#                             NGFS-Current Policies                              False
#                             NGFS-Nationally Determined Contributions (NDCs)    False
#                             NGFS-Net Zero 2050                                 False
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                      False
#                             NGFS-Current Policies                              False
#                             NGFS-Nationally Determined Contributions (NDCs)    False
#                             NGFS-Net Zero 2050                                 False
#
#                                                                             warming-category
# model                       scenario
# MESSAGEix-GLOBIOM 1.1-M-R12 NGFS-Below 2C                                           below 2C
#                             NGFS-Current Policies                                   above 2C
#                             NGFS-Nationally Determined Contributions (NDCs)         above 2C
#                             NGFS-Net Zero 2050                                      below 2C
# REMIND-MAgPIE 3.0-4.4       NGFS-Below 2C                                           below 2C
#                             NGFS-Current Policies                                   above 2C
#                             NGFS-Nationally Determined Contributions (NDCs)         above 2C
#                             NGFS-Net Zero 2050                                      below 2C

# %% [markdown]
# We can now use this categorization to assign styles for the plots of other variables.

# %%
(
    df.filter(variable="Primary Energy|Gas")
    .plot(color="warming-category", linestyle="model", fill_between=True, final_ranges=True, legend={"loc": "outside right"})
)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# <Axes: title={'center': 'region: World - variable: Primary Energy|Gas'}, xlabel='Year', ylabel='EJ/yr'>

# %% [markdown]
# Of course, **pyam** also supports a lot of other plot types and styles -
# check out the [plotting gallery](https://pyam-iamc.readthedocs.io/en/stable/gallery/index.html)!

# %% [markdown]
# ## Algebraic operations
#
# **pyam** can also perform algebraic directly on the timeseries data.
#
# All algebraic-operations functions (
# [add()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.add),
# [subtract()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.subtract),
# [multiply()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.multiply),
# [divide()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.divide)
# ) follow the syntax:
#
# ```
# df.<method>(a, b, c) => a <op> b = c
# ```
#
# If possible, **pyam** will try to keep the unit consistent during the operation.
# This feature is supported by the **pint** and the **iam-units** packages,
# see [here](https://github.com/iamconsortium/units).
#
# ## Computing the amount of primary energy that is not coal
#
# First, we subtract coal from total primary energy and draw a simple plot.

# %%
df.subtract("Primary Energy", "Primary Energy|Coal", "diff").plot(legend=False);
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/dtypes/cast.py:1598: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:1121: SyntaxWarning: invalid escape sequence '\g'
#   """Convert all timeseries data having *current* units to new units.
# ---------------------------------------------------------------------------
# DimensionalityError                       Traceback (most recent call last)
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:1095, in Quantity.__rsub__(self, other)
#    1094 else:
# -> 1095     return -self._add_sub(other, operator.sub)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:115, in check_implemented.<locals>.wrapped(self, *args, **kwargs)
#     114     return NotImplemented
# --> 115 return f(self, *args, **kwargs)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:984, in Quantity._add_sub(self, other, op)
#     983 else:
# --> 984     raise DimensionalityError(self._units, "dimensionless")
#     985 return self.__class__(magnitude, units)
#
# DimensionalityError: Cannot convert from 'exajoule / year' to 'dimensionless'
#
# During handling of the above exception, another exception occurred:
#
# DimensionalityError                       Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df.subtract("Primary Energy", "Primary Energy|Coal", "diff").plot(legend=False);
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:1925, in IamDataFrame.subtract(self, a, b, name, axis, fillna, ignore_units, append)
#    1877 """Compute the difference of timeseries data items `a` and `b` along an `axis`
#    1878
#    1879 This function computes `a - b`. If `a` or `b` are lists, the method applies
#    (...)
#    1922 For example, the unit :code:`EJ/yr` may be reformatted to :code:`EJ / a`.
#    1923 """
#    1924 kwds = dict(axis=axis, fillna=fillna, ignore_units=ignore_units)
# -> 1925 _value = _op_data(self, name, "subtract", **kwds, a=a, b=b)
#    1927 # append to `self` or return as `IamDataFrame`
#    1928 return self._finalize(_value, append=append)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/_ops.py:122, in _op_data(df, name, method, axis, fillna, args, ignore_units, **kwds)
#     119             kwds[key] = _data[key]
#     121 # apply method and check that returned object is valid
# --> 122 result = method(*_args, **kwds)
#     123 if not isinstance(result, pd.Series):
#     124     msg = f"Value returned by `{method.__name__}` cannot be cast to an IamDataFrame"
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/_ops.py:15, in subtract(a, b)
#      14 def subtract(a, b):
# ---> 15     return operator.sub(*_make_series(a, b))
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# -> 6115     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:1095, in Quantity.__rsub__(self, other)
#    1093     return other - self.to_timedelta()
#    1094 else:
# -> 1095     return -self._add_sub(other, operator.sub)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:115, in check_implemented.<locals>.wrapped(self, *args, **kwargs)
#     113 elif isinstance(other, list) and other and isinstance(other[0], type(self)):
#     114     return NotImplemented
# --> 115 return f(self, *args, **kwargs)
#
# File ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pint/quantity.py:984, in Quantity._add_sub(self, other, op)
#     979         magnitude = op(
#     980             self.to(units)._magnitude,
#     981             _to_magnitude(other, self.force_ndarray, self.force_ndarray_like),
#     982         )
#     983     else:
# --> 984         raise DimensionalityError(self._units, "dimensionless")
#     985     return self.__class__(magnitude, units)
#     987 if not self.dimensionality == other.dimensionality:
#
# DimensionalityError: Cannot convert from 'exajoule / year' to 'dimensionless'

# %% [markdown]
# ### Computing coal as a share of primary energy
#
# Next, we can also compute the share of coal relative to total primary energy, and again draw the plot.

# %%
df.divide("Primary Energy|Coal", "Primary Energy", "Share of coal").plot(legend=dict(loc="outside right"))
# Out:
# <Axes: title={'center': 'region: World - variable: Share of coal'}, xlabel='Year', ylabel='Value'>

# %% [markdown]
# Note that **pyam** has automatically changed the unit on the y-axis,
# because dividing *EJ/yr* by *EJ/yr* yiels a dimensionless value.

# %% [markdown]
# ### Compute ratio of energy sources between different scenarios
#
# So far, we used the algebraic operations on the (default) *variable* axis.
# But **pyam** also supports these operations on any other axis of the timeseries data!
#
# Now, we compute the relative indicator between the *Net Zero 2050* and the *Current Policies* scenarios,
# and again plot the resulting timeseries data.
# For simplicity, we only perform this computation on primary-energy values (including the sub-categories)
# of the *REMIND* model.

# %%
df_pe = df.filter(model="REMIND-MAgPIE 3.0-4.4", variable="Primary Energy*")
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)

# %%
(
    df_pe.divide("NGFS-Net Zero 2050", "NGFS-Current Policies", "diff", axis="scenario")
    .plot(legend=dict(loc="outside right"))
)
# Out:
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# /Users/christines/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py:2508: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   index = pd.unique(index)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/y3/1cxltp3j6rn27pc3lkybs7hw0000gn/T/ipykernel_54073/1780998835.py in ?()
#       1 (
# ----> 2     df_pe.divide("NGFS-Net Zero 2050", "NGFS-Current Policies", "diff", axis="scenario")
#       3     .plot(legend=dict(loc="outside right"))
#       4 )
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, a, b, name, axis, fillna, ignore_units, append)
#    2034         kwds = dict(axis=axis, fillna=fillna, ignore_units=ignore_units)
#    2035         _value = _op_data(self, name, "divide", **kwds, a=a, b=b)
#    2036
#    2037         # append to `self` or return as `IamDataFrame`
# -> 2038         return self._finalize(_value, append=append)
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, data, append, **args)
#     232             self.append(data, **args, inplace=True)
#     233         else:
#     234             if data is None or data.empty:
#     235                 return _empty_iamframe(self.dimensions + ["value"])
# --> 236             return IamDataFrame(data, meta=self.meta, **args)
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, data, meta, index, **kwargs)
#     141                 raise ValueError(msg + f"(index={data.index.names})")
#     142             for attr, value in data.__dict__.items():
#     143                 setattr(self, attr, value)
#     144         else:
# --> 145             self._init(data, meta, index=index, **kwargs)
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/core.py in ?(self, data, meta, index, **kwargs)
#     189
#     190         # if given explicitly, merge meta dataframe after downselecting
#     191         if meta is not None:
#     192             meta = meta.loc[self.meta.index.intersection(meta.index)]
# --> 193             self.meta = merge_meta(meta, self.meta, ignore_conflict=True)
#     194
#     195         # if initializing from xlsx, try to load `meta` table from file
#     196         if meta_sheet and isinstance(data, Path) and data.suffix == ".xlsx":
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pyam/utils.py in ?(left, right, ignore_conflict)
#     412         )
#     413
#     414     # join `other.meta` for new scenarios (`diff`)
#     415     if not diff.empty:
# --> 416         left = left.append(right.loc[diff, :], sort=False)
#     417
#     418     # remove any columns that are all-nan
#     419     return left.dropna(axis=1, how="all")
#
# ~/opt/miniconda3/envs/pyam/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import matplotlib.pyplot as plt

# %%
As a final illustration, this tutorials shows how to use **matplotlib** and **pyam** to create several plots next to each other.

# %%
baseline = "NGFS-Current Policies"
scenario = set(df.scenario) - set([baseline])

# We first create a matplotlib figure with several "axes" objects (i.e., individual plots)
fig, ax = plt.subplots(1, len(scenario), figsize=(15, 5), sharey=True)

# Then, we iterate over the axes, plotting the results for each scenario as we go along
for i, s in enumerate(scenario):
    (
        df_pe.divide(s, baseline, "diff", axis="scenario")
        .plot(ax=ax[i], legend=dict(loc="outside right") if i==len(scenario) - 1 else False)
    )

    # We can also modify the axes objects directly to produce a better figure
    ax[i].set_title(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 10
#       7 # Then, we iterate over the axes, plotting the results for each scenario as we go along
#       8 for i, s in enumerate(scenario):
#       9     (
# ---> 10         df_pe.divide(s, baseline, "diff", axis="scenario")
#      11         .plot(ax=ax[i], legend=dict(loc="outside right") if i==len(scenario) - 1 else False)
#      12     )
#      14     # We can also modify the axes objects directly to produce a better figure
#      15     ax[i].set_title(s)
#
# NameError: name 'df_pe' is not defined

# %% [markdown]
# ## Query any IIASA Scenario Explorer database
#
# For this tutorial, the data is included as an Excel spreadsheet for simplicity.
#
# However, a lot of scenario data is available via the **IIASA Scenario Explorer** infrastructure,
# for example the scenario ensemble supporting the **IPCC Sixth Assessment Report (AR6)**
# ([link](http://data.ece.iiasa.ac.at/ar6/#/login)).
#
# You can easily query scenario data hosted by IIASA directly from a Python environment
# (or R, see [here](https://pyam-iamc.readthedocs.io/en/stable/R_tutorials/pyam_R_tutorial.html))
# using the **pyam** package.
#
# See this [tutorial](https://pyam-iamc.readthedocs.io/en/stable/tutorials/iiasa_dbs.html)
# for more information!

# %% [markdown]
# <div class="alert alert-info">
#
# **Curious about more pyam features?** Check out the all the pyam tutorials on our [ReadTheDocs page](https://pyam-iamc.readthedocs.io/en/stable/tutorials.html)!
#
# </div>
